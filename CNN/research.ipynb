# %% [markdown]
# <h1>16 oct</h1>

# %%
import tensorflow as tf
import cv2 as cv
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
image_file_path = r"C:\Users\ashis\OneDrive\Desktop\jecrc\upflairs_AIML_training_codes\CNN\Data\images\cats\cat_2.jpg"
img = Image.open(image_file_path)

# %%
img

# %%
img_arr = np.array(img)
img_arr

# %%
img_file_path = r"C:\Users\ashis\OneDrive\Desktop\jecrc\upflairs_AIML_training_codes\CNN\Data\images\cats\cat_60.jpg"
img = Image.open(img_file_path)
img

# %%
img_array = np.array(img)
img_array

# %%
img_dire_path = r"C:\Users\ashis\OneDrive\Desktop\jecrc\upflairs_AIML_training_codes\CNN\Data\images"
# path_dict = {"cats":[],"dogs":[]}

# %%
os.listdir(img_dire_path)

# %%
img_dire_path+'\\'+'cats'

# %%
cat_dir_path = os.path.join(img_dire_path, 'cats')
dog_dir_path = os.path.join(img_dire_path, 'dogs')
print("cat directory path :",cat_dir_path)
print("dog directory path :",dog_dir_path)

# %%
print("Total no. of cat images in my folder :",len(os.listdir(cat_dir_path)))
print("Total no. of dog images in my folder :",len(os.listdir(dog_dir_path)))

# %%
os.listdir(cat_dir_path)

# %%
for filename in os.listdir(cat_dir_path):
    # print(filename)
    print(os.path.join(cat_dir_path, filename))

# %%
path_dict = {"cats":[],"dogs":[]}
for filename in os.listdir(cat_dir_path):
    path_dict['cats'].append(os.path.join(cat_dir_path, filename))

for filename in os.listdir(dog_dir_path):
    path_dict['dogs'].append(os.path.join(dog_dir_path, filename))

# %%
path_dict

# %%
path_dict['cats']

# %%
len(path_dict['cats'])

# %%
path_dict['dogs']

# %%
img = Image.open(path_dict['cats'][250])
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2032x1016>

# %%
img = Image.open(path_dict['dogs'][75])
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x601>
